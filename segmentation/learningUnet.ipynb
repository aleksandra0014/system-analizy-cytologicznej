# %% [markdown]
# ## Imports

# %%
import torch
from dataset import CellNucleusDataset, train_loader, val_loader
from modelsUnet import UNet, train, UNet4Levels
import torch.nn as nn
from torch.utils.data import DataLoader
import os

# %% [markdown]
# ## Parameters

# %%
batch_size = 16
learning_rate = 1e-4
num_epochs = 50
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Training

# %%
model = UNet4Levels(in_channels=3, out_channels=2)
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

train(model, train_loader, val_loader, optimizer, device, epochs=num_epochs, log_dir="runs/unet_cell_nucleus/0908", model_path="unet4_cell_nucleus_16_0_0001_50_1210.pth")

torch.save(model.state_dict(), "unet4_cell_nucleus_16_0_0001_50_1210.pth")
# Out:
# Epoch 1/50: 100%|██████████| 16/16 [03:04<00:00, 11.54s/it, loss=0.655]
# Epoch 1 Train loss: 0.6923
# Epoch 1 Val loss: 0.7513
# Best model saved (val loss = 0.7513)
# Epoch 2/50: 100%|██████████| 16/16 [03:08<00:00, 11.75s/it, loss=0.615]
# Epoch 2 Train loss: 0.6245
# Epoch 2 Val loss: 0.6670
# Best model saved (val loss = 0.6670)
# Epoch 3/50: 100%|██████████| 16/16 [03:14<00:00, 12.18s/it, loss=0.601]
# Epoch 3 Train loss: 0.6015
# Epoch 3 Val loss: 0.5879
# Best model saved (val loss = 0.5879)
# Epoch 4/50: 100%|██████████| 16/16 [03:16<00:00, 12.30s/it, loss=0.638]
# Epoch 4 Train loss: 0.5836
# Epoch 4 Val loss: 0.5727
# Best model saved (val loss = 0.5727)
# Epoch 5/50: 100%|██████████| 16/16 [03:14<00:00, 12.16s/it, loss=0.578]
# Epoch 5 Train loss: 0.5760
# Epoch 5 Val loss: 0.5726
# Best model saved (val loss = 0.5726)
# Epoch 6/50: 100%|██████████| 16/16 [03:16<00:00, 12.29s/it, loss=0.561]
# Epoch 6 Train loss: 0.5665
# Epoch 6 Val loss: 0.5463
# ...

# %%
model = UNet4Levels(in_channels=3, out_channels=2)
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

train(model, train_loader, val_loader, optimizer, device, epochs=40, log_dir="runs/unet_cell_nucleus/610", model_path="unet_cell_nucleus_4levels_610_50.pth")

torch.save(model.state_dict(), "unet_cell_nucleus_4levels_610_50.pth")
# Out:
# Epoch 1/40: 100%|██████████| 64/64 [02:47<00:00,  2.61s/it, loss=0.598]
# Epoch 1 Train loss: 0.6647
# Epoch 1 Val loss: 0.6403
# Best model saved (val loss = 0.6403)
# Epoch 2/40: 100%|██████████| 64/64 [03:01<00:00,  2.83s/it, loss=0.657]
# Epoch 2 Train loss: 0.5974
# Epoch 2 Val loss: 0.5937
# Best model saved (val loss = 0.5937)
# Epoch 3/40: 100%|██████████| 64/64 [02:59<00:00,  2.80s/it, loss=0.62]
# Epoch 3 Train loss: 0.5641
# Epoch 3 Val loss: 0.5555
# Best model saved (val loss = 0.5555)
# Epoch 4/40: 100%|██████████| 64/64 [03:03<00:00,  2.86s/it, loss=0.548]
# Epoch 4 Train loss: 0.5430
# Epoch 4 Val loss: 0.5402
# Best model saved (val loss = 0.5402)
# Epoch 5/40: 100%|██████████| 64/64 [03:07<00:00,  2.93s/it, loss=0.452]
# Epoch 5 Train loss: 0.5259
# Epoch 5 Val loss: 0.5366
# Best model saved (val loss = 0.5366)
# Epoch 6/40: 100%|██████████| 64/64 [03:08<00:00,  2.95s/it, loss=0.549]
# Epoch 6 Train loss: 0.5095
# Epoch 6 Val loss: 0.4846
# ...

# %%
from models import UNet
model = UNet(in_channels=3, out_channels=2)
model.load_state_dict(torch.load(r"C:\Users\aleks\OneDrive\Documents\inzynierka\segmentation\models_paths\unet\unet_cell_nucleus_0208.pth"))
print(model)
# Out:
# UNet(
#   (encoder1): DoubleConv(
#     (double_conv): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (3): ReLU(inplace=True)
#     )
#   )
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (encoder2): DoubleConv(
#     (double_conv): Sequential(
#       (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (3): ReLU(inplace=True)
#     )
#   )
#   (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (encoder3): DoubleConv(
#     (double_conv): Sequential(
#       (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
# ...

# %%
model.load_state_dict(torch.load(r"C:\Users\aleks\OneDrive\Documents\inzynierka\segmentation\models_paths\unet\unet_cell_nucleus_0908_50.pth"))
print(model)
# Out:
# UNet(
#   (encoder1): DoubleConv(
#     (double_conv): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (3): ReLU(inplace=True)
#     )
#   )
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (encoder2): DoubleConv(
#     (double_conv): Sequential(
#       (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (3): ReLU(inplace=True)
#     )
#   )
#   (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (encoder3): DoubleConv(
#     (double_conv): Sequential(
#       (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
# ...

# %% [markdown]
# ## Importy

# %%
from dataset import train_dataset, test_dataset, val_dataset, class_counts
from torch.utils.data import DataLoader
from models import CytologyClassifier
from models_testing import test_model
from dataset import test_dataset
from torch.utils.data import DataLoader

# %% [markdown]
# ## Parametry

# %%
batch_size = 16
lr = 0.0001
num_epochs = 50

# %% [markdown]
# ## Podział na loadery

# %%
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size)
test_loader = DataLoader(test_dataset, batch_size=batch_size)

# %% [markdown]
# ## Nauka modeli

# %%
classifier = CytologyClassifier(num_classes=3, lr=0.0001, architecture='resnet18', class_counts=class_counts)
classifier.train(train_loader=train_loader, val_loader=val_loader, num_epochs=50, save_best_path=r'classification_models\resnet18\16_0_0001_50_1110.pth')
# Out:
# c:\Users\aleks\OneDrive\Documents\inzynierka\inz\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\aleks\OneDrive\Documents\inzynierka\inz\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 1/50 - Train Loss: 0.4637 | Val Loss: 0.1956 | Val F1: 0.9327
#  🔥 Best model (F1=0.9327) saved to classification_models\resnet18\16_0_0001_50_1110.pth
#
# Epoch 2/50 - Train Loss: 0.1063 | Val Loss: 0.1747 | Val F1: 0.8878
# ...

# %%
classifier = CytologyClassifier(num_classes=3, lr=0.0001, architecture='custom_cnn', class_counts=class_counts)
classifier.train(train_loader=train_loader, val_loader=val_loader, num_epochs=50, save_best_path=r'classification_models\custom_cnn\16_0_0001_50_1110.pth')
# Out:
# Epoch 1/50 - Train Loss: 0.9167 | Val Loss: 0.8079 | Val F1: 0.5259
#  🔥 Best model (F1=0.5259) saved to classification_models\custom_cnn\16_0_0001_50_1110.pth
#
# Epoch 2/50 - Train Loss: 0.6358 | Val Loss: 0.4901 | Val F1: 0.7524
#  🔥 Best model (F1=0.7524) saved to classification_models\custom_cnn\16_0_0001_50_1110.pth
#
# Epoch 3/50 - Train Loss: 0.5712 | Val Loss: 0.4936 | Val F1: 0.7273
#  ⏳ No improvement in val loss (1/10)
#
# Epoch 4/50 - Train Loss: 0.5712 | Val Loss: 0.4358 | Val F1: 0.7274
#  🔥 Best model (F1=0.7274) saved to classification_models\custom_cnn\16_0_0001_50_1110.pth
#
# Epoch 5/50 - Train Loss: 0.4584 | Val Loss: 0.4894 | Val F1: 0.7174
#  ⏳ No improvement in val loss (1/10)
#
# Epoch 6/50 - Train Loss: 0.5339 | Val Loss: 0.4115 | Val F1: 0.7709
#  🔥 Best model (F1=0.7709) saved to classification_models\custom_cnn\16_0_0001_50_1110.pth
#
# Epoch 7/50 - Train Loss: 0.4128 | Val Loss: 0.4154 | Val F1: 0.7537
#  ⏳ No improvement in val loss (1/10)
#
# ...

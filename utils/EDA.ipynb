# %%
import pandas as pd
import cv2
# from helpers import get_folder_summary

# %%
df = pd.read_csv(r'C:\Users\aleks\OneDrive\Documents\inzynierka\wyniki_gridsearch.csv')
df
# Out:
#    architecture      lr  batch_size  epochs  mean_accuracy  std_accuracy  \
# 0      resnet18  0.0010          16      20      87.762478      4.281390
# 1      resnet18  0.0010          32      20      90.169248      3.516106
# 2      resnet18  0.0001          16      20      93.032129      3.098935
# 3      resnet18  0.0001          32      20      91.838784      2.230302
# 4         vgg16  0.0010          16      20      91.368330      1.393699
# 5         vgg16  0.0010          32      20      90.172117      2.965010
# 6         vgg16  0.0001          16      20      91.606426      2.152618
# 7         vgg16  0.0001          32      20      91.127367      2.994067
# 8    custom_cnn  0.0010          16      20      72.403901      3.361647
# 9    custom_cnn  0.0010          32      20      80.321285      7.007228
# 10   custom_cnn  0.0001          16      20      86.336776      2.874715
# 11   custom_cnn  0.0001          32      20      86.572002      2.955043
#
# ...

# %%
from helpers import get_folder_summary


data_path = r'C:\Users\aleks\OneDrive\Documents\inzynierka\data\data_single'
df = get_folder_summary(data_path)
df
# Out:
#   Folder  Liczba plików  Minimalna szerokość  Minimalna wysokość  \
# 0   HSIL            124                 1130                1129
# 1   LSIL             60                 1130                 986
# 2   NSIL            233                 1130                 958
#
#    Maksymalna szerokość  Maksymalna wysokość
# 0                  1130                 1130
# 1                  1130                 1130
# 2                  2510                 1540

# %%
data_path = r'C:\Users\aleks\OneDrive\Documents\inzynierka\data\LBC_slides'
df = get_folder_summary(data_path)
df
# Out:
#                  Folder  Liczba plików  Minimalna szerokość  \
# 0            HSILpow 10             62                 2510
# 1            HSILpow 40             62                 2510
# 2  LSILkoilocyty/pow 10             29                 2418
# 3  LSILkoilocyty/pow 40             32                 2510
# 4            LSILpow 40             35                 2510
# 5           LSILpow. 10             30                 2510
# 6            NSILpow 40            157                 1540
# 7           NSILpow. 10             76                 1540
#
#    Minimalna wysokość  Maksymalna szerokość  Maksymalna wysokość
# 0                1540                  2510                 1540
# 1                1479                  2510                 1540
# 2                1540                  2510                 1540
# 3                1540                  2540                 1540
# 4                1540                  2510                 1540
# ...

# %%
data_path = r'C:\Users\aleks\OneDrive\Documents\inzynierka\data\data_mendeley'
df = get_folder_summary(data_path)
df
# Out:
#                                     Folder  Liczba plików  \
# 0    High squamous intra-epithelial lesion            163
# 1     Low squamous intra-epithelial lesion            113
# 2  Negative for Intraepithelial malignancy            612
#
#    Minimalna szerokość  Minimalna wysokość  Maksymalna szerokość  \
# 0                 2048                1536                  2048
# 1                 2048                1536                  2048
# 2                 2048                1536                  2048
#
#    Maksymalna wysokość
# 0                 1536
# 1                 1536
# 2                 1536

# %%
data_path = r'C:\Users\aleks\OneDrive\Documents\inzynierka\data_yolo'
df = get_folder_summary(data_path)
df
# Out:
#                                     Folder  Liczba plików  \
# 0        data_mine_labelstrain_data/images             66
# 1        data_mine_labelstrain_data/labels              0
# 2               data_mine_labelsval/images              6
# 3               data_mine_labelsval/labels              0
# 4                      data_synteticimages            250
# 5                      data_synteticlabels              0
# 6                  syntetic_and_mineimages            170
# 7                  syntetic_and_minelabels              0
# 8              syntetic_and_mine_valimages             29
# 9              syntetic_and_mine_vallabels              0
# 10                    testtest_hybrid/HSIL             16
# 11                    testtest_hybrid/LSIL             16
# 12                 testtest_hybrid_23/HSIL             16
# 13        testtest_hybrid_23/HSIL-mendeley             16
# 14                 testtest_hybrid_23/LSIL             16
# ...
